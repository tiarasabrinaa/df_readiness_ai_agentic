# %%
import pandas as pd

data = pd.read_csv(f"data_wisang.csv", delimiter=";")
data
# Out:
#      Package                  Komponen              Level  \
# 0          0                  Strategy          Recognize
# 1          0                  Strategy             Define
# 2          0                  Strategy            Measure
# 3          0                  Strategy            Analyze
# 4          0                  Strategy  Improve & Control
# ..       ...                       ...                ...
# 361        0  Personal Data Protection             Define
# 362        0  Personal Data Protection            Measure
# 363        0  Personal Data Protection            Analyze
# 364        0  Personal Data Protection  Improve & Control
# 365        0  Personal Data Protection            Sustain
#
#                                              Indikator  \
# 0                    Program kesiapan forensik digital
# 1                    Program kesiapan forensik digital
# 2                    Program kesiapan forensik digital
# ...
